# %% [markdown]
# <a href="https://colab.research.google.com/github/magesh03037/edify-assignments/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_493/2916085370.py in <cell line: 0>()
#       1 a = ("zebra", "sabari")
# ----> 2 print(tuple(reverse(a)))
#
# NameError: name 'reverse' is not defined

# %%
thisset={"google","chrome","colab","docx"}
x=thisset.pop()
print(x)
print(thisset)
# Out:
# colab
# {'google', 'chrome', 'docx'}

# %%
thisset={"google","chrome","colab","docx"}
thisset.discard("docx")
print(thisset)
# Out:
# {'colab', 'google', 'chrome'}

# %%
thisset={"google","chrome","colab","docx"}
del thisset
print(thisset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_493/663796069.py in <cell line: 0>()
#       1 thisset={"google","chrome","colab","docx"}
#       2 del thisset
# ----> 3 print(thisset)
#
# NameError: name 'thisset' is not defined

# %%
thisset={"google","chrome","colab","docx"}
thisset.clear()
print(thisset)
# Out:
# set()

# %%
thisset={"google","chrome","colab","docx"}
thisset.remove("docx")
print(thisset)
# Out:
# {'colab', 'google', 'chrome'}

# %%
thisset={"google","chrome","colab"}
thisset.add("docx")
print(thisset)
# Out:
# {'colab', 'google', 'chrome', 'docx'}

# %%
my_dict = {"brand": "Ford", "model": "Mustang", "year": 1964}
my_dict["year"] = 2026
print(my_dict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2026}

# %%
my_dict = {"brand": "Ford", "model": "Mustang", "year": 1964}
print(my_dict["brand"])
print(my_dict["model"])
print(my_dict["year"])
# Out:
# Ford
# Mustang
# 1964

# %%
my_tuple = ("apple", "banana", "cherry")
my_tuple = (my_tuple[0], my_tuple[2])
print(my_tuple)
# Out:
# ('apple', 'cherry')

# %%
my_tuple = ("apple", "banana", "cherry")
del my_tuple
print(my_tuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_493/1884027725.py in <cell line: 0>()
#       1 my_tuple = ("apple", "banana", "cherry")
#       2 del my_tuple
# ----> 3 print(my_tuple[0])
#       4
#
# NameError: name 'my_tuple' is not defined

# %%
my_tuple = ("apple", "banana", "cherry")
print(my_tuple * 2)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'banana', 'cherry')

# %%
my_tuple = ("apple", "banana", "cherry")
print("The whole tuple:", my_tuple)
print("The first item:", my_tuple[0])
# Out:
# The whole tuple: ('apple', 'banana', 'cherry')
# The first item: apple

# %%
list=["fruits","vegetables","mutton"];
list.sort();
print(list);
# Out:
# ['fruits', 'mutton', 'vegetables']
